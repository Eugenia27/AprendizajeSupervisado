# %% [markdown]
# # Diplodatos Kaggle Competition

# %% [markdown]
# #### Autor: Ferraro, María Eugenia

# %% [markdown]
# We present this peace of code to create the baseline for the competition, and as an example of how to deal with these kind of problems. The main goals are that you:
#
# 1. Learn
# 1. Try different models and see which one fits the best the given data
# 1. Get a higher score than the given one in the current baseline example
# 1. Try to get the highest score in the class :)

# %%
import modelos
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### SE TRABAJA SOLO CON LA METRICA ACCURACY, PUES EN ESTA SE BASA LA COMPETENCIA.

# %%
def hiperparametros(clf,params):
    print('MODELO:',clf,'\nPARAMETROS: ',params)
    model = GridSearchCV(clf, params, scoring='accuracy', cv=3, iid=False,verbose=15, n_jobs=-1)
    model.fit(X_train.drop(["PID"], axis=1), y_train)
    best_model = model.best_estimator_

    print('BEST MODEL ACCURACY: ',model.best_score_)
    print(best_model)
    return best_model, model.best_score_

# %%
def transform_columns(df):
    df = df.drop(["Description"], axis=1)
    df.Type = df.Type.replace({1: 'Dog', 2: 'Cat'})
    df.Gender = df.Gender.replace({1:'Male', 2:'Female', 3:'Mixed'})
    df.MaturitySize = df.MaturitySize.replace({1:'S', 2:'M', 3:'L', 4:'XL', 0:'N/A'})
    df.FurLength = df.FurLength.replace({1:'S', 2:'M', 3:'L', 0:'N/A'})
    df.Vaccinated = df.Vaccinated.replace({1:'T', 2:'N', 3:'N/A'})
    df.Dewormed = df.Dewormed.replace({1:'T', 2:'F', 3:'N/A'})
    df.Sterilized = df.Sterilized.replace({1:'T', 2:'F', 3:'N/A'})
    df.Health = df.Health.replace({1:'Healthy', 2: 'MinorInjury', 3:'SeriousInjury', 0: 'N/A'})
    df.Color1 = df.Color1.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
    df.Color2 = df.Color2.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
    df.Color3 = df.Color3.replace(dict(list(zip(color.ColorID, color.ColorName)) + [(0, "N/A")]))
    df.Breed1 = df.Breed1.replace(dict(list(zip(breed.BreedID, breed.BreedName)) + [(0, "N/A")]))
    df.Breed2 = df.Breed2.replace(dict(list(zip(breed.BreedID, breed.BreedName)) + [(0, "N/A")]))
    return df


def transform_data(train_data_fname, test_data_fname):
    df_train = pd.read_csv(train_data_fname)
    df_train = transform_columns(df_train)
    df_test = pd.read_csv(test_data_fname)
    df_test = transform_columns(df_test)
    
    df = pd.concat([df_train, df_test], sort=True)

    # set dummy variables for everything
    # except from Age, Quantity, Fee
    df = pd.get_dummies(df)
    
    # get train and test back
    n = len(df_train)
    df_train = df.iloc[:n]
    df_test = df.iloc[n:]
    
    y = df_train['AdoptionSpeed']
    X = df_train.drop('AdoptionSpeed', axis=1)
    yy = None
    XX = df_test.drop('AdoptionSpeed', axis=1)

    return X, y, XX, yy

# %%
# load the given labels
breed = pd.read_csv('../data/breed_labels.csv')
color = pd.read_csv('../data/color_labels.csv')
state = pd.read_csv('../data/state_labels.csv')

# %%
X, y, XX, yy = transform_data("../data/train.csv", "../data/test.csv")
X_train, X_valid, y_train, y_valid = train_test_split(X,
                                                      y,
                                                      test_size=0.3,
                                                      random_state=113)

# %%
dic = modelos.modelo_familia()
modelos.modelo_familia()
# Out:
# {'LINEAL': {1: 'LogisticRegression',
#   2: 'RidgeClassifier',
#   3: 'SGDClassifier',
#   4: 'Perceptron',
#   5: 'PassiveAggressiveClassifier'},
#  'SVM': {1: 'LinearSVC', 2: 'NuSVC', 3: 'SVC'},
#  'TREE': {1: 'DecisionTreeClassifier'},
#  'NEIGHBORS': {1: 'KNeighborsClassifier',
#   2: 'NearestCentroid',
#   3: 'RadiusNeighborsClassifier'},
#  'SEMI_SUPERVISED': {1: 'LabelPropagation', 2: 'LabelSpreading'},
#  'ENSEMBLE': {1: 'RandomForestClassifier'},
#  'DISCRIMINANT_ANALYSIS': {1: 'LinearDiscriminantAnalysis',
#   2: 'QuadraticDiscriminantAnalysis'},
#  'NEURAL_NETWORK': {1: 'MLPClassifier'}}

# %%
resultados = []

# %%
m = 0
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# LINEAL
# MODELO: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=113, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# PARAMETROS:  {'multi_class': ('ovr', 'multinomial'), 'C': (1e-05, 0.001, 0.1, 10.0), 'solver': ('lbfgs', 'sag', 'saga', 'newton-cg'), 'max_iter': [1000]}
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   25.5s
# ...

# %%
m = 0
sm = 2
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# LINEAL
# MODELO: RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=113, solver='auto',
#         tol=0.001)
# PARAMETROS:  {'alpha': (1e-05, 0.001, 0.1, 10), 'solver': ('svd', 'cholesky', 'lsqr', 'saga'), 'max_iter': [1000]}
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   15.9s
# ...

# %%
m=0
sm=3
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# LINEAL
# MODELO: SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=113, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False)
# PARAMETROS:  {'loss': ('hinge', 'log', 'perceptron'), 'penalty': ['l2'], 'learning_rate': ('optimal', 'invscaling', 'adaptive'), 'alpha': (1e-05, 0.001, 0.1, 10), 'eta0': (1e-05, 0.001, 0.1, 10), 'max_iter': [100]}
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    4.2s
# ...

# %%
m = 0
sm = 4
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# LINEAL
# MODELO: Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#       fit_intercept=True, max_iter=None, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty=None, random_state=113, shuffle=True, tol=None,
#       validation_fraction=0.1, verbose=0, warm_start=False)
# PARAMETROS:  {'penalty': ('l1', 'l2', 'elasticnet'), 'alpha': (1e-05, 0.001, 0.1, 10), 'eta0': (1e-05, 0.001, 0.1, 10), 'max_iter': [1000]}
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.5min
# ...

# %%
m = 1
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# SVM
# MODELO: LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=113, tol=0.0001,
#      verbose=0)
# PARAMETROS:  {'loss': ['hinge'], 'multi_class': ['ovr'], 'C': (1e-05, 0.001, 0.1, 10, 100), 'max_iter': [1000]}
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done   2 out of  15 | elapsed:    6.1s remaining:   39.6s
# [Parallel(n_jobs=-1)]: Done   4 out of  15 | elapsed:    6.2s remaining:   17.0s
# [Parallel(n_jobs=-1)]: Done   6 out of  15 | elapsed:    7.3s remaining:   11.0s
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    7.4s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  15 | elapsed:   11.7s remaining:    5.9s
# ...

# %%
m = 2
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# TREE
# MODELO: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=113,
#             splitter='best')
# PARAMETROS:  {'criterion': ('gini', 'entropy'), 'splitter': ('best', 'random'), 'max_depth': (None, 10, 30, 50, 100), 'min_samples_split': (2, 10, 50, 100, 200), 'min_samples_leaf': (1, 2, 5, 10, 50)}
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
# ...

# %%
m = 3
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# NEIGHBORS
# MODELO: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# PARAMETROS:  {'n_neighbors': (1, 2, 3, 4, 5, 7), 'metric': ('euclidean', 'manhattan', 'chebyshev', 'minkowski')}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   12.7s
# ...

# %%
m = 4
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# SEMI_SUPERVISED
# MODELO: LabelPropagation(alpha=None, gamma=20, kernel='rbf', max_iter=1000,
#          n_jobs=None, n_neighbors=7, tol=0.001)
# PARAMETROS:  {'kernel': ('rbf', 'knn'), 'n_neighbors': (1, 2, 3, 4, 5, 10, 15), 'gamma': (1e-05, 0.001, 0.1, 1, 20, 100), 'max_iter': [1000]}
# Fitting 3 folds for each of 84 candidates, totalling 252 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.5s
# ...

# %%
m = 4
sm = 2
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# SEMI_SUPERVISED
# MODELO: LabelSpreading(alpha=0.2, gamma=20, kernel='rbf', max_iter=30, n_jobs=None,
#         n_neighbors=7, tol=0.001)
# PARAMETROS:  {'kernel': ('rbf', 'knn'), 'n_neighbors': (1, 2, 3, 4, 5, 10, 15), 'alpha': (1e-05, 0.001, 0.1), 'max_iter': [1000]}
# Fitting 3 folds for each of 42 candidates, totalling 126 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   42.6s
# ...

# %%
pd.DataFrame(resultados[2:])
# Out:
#                                         mejor_modelo   puntaje
# 0  SGDClassifier(alpha=1e-05, average=False, clas...  0.272718
# 1  Perceptron(alpha=0.1, class_weight=None, early...  0.214657
# 2  LinearSVC(C=1e-05, class_weight=None, dual=Tru...  0.263956
# 3  DecisionTreeClassifier(class_weight=None, crit...  0.370192
# 4  KNeighborsClassifier(algorithm='auto', leaf_si...  0.327930
# 5  LabelPropagation(alpha=None, gamma=0.1, kernel...  0.338868
# 6  LabelSpreading(alpha=0.1, gamma=20, kernel='kn...  0.343996
# 7  (DecisionTreeClassifier(class_weight=None, cri...  0.324420

# %% [markdown]
# ## Cambio tamaño de conjuntos de entrenamiento y test:  0.3 -> 0.2

# %%
X, y, XX, yy = transform_data("../data/train.csv", "../data/test.csv")
X_train, X_valid, y_train, y_valid = train_test_split(X,
                                                      y,
                                                      test_size=0.2,
                                                      random_state=113)

# %%
m = 5
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(113,modelo,sm)
params = {'criterion':('gini', 'entropy'), 'min_samples_leaf':(1, 2, 5,10),
              'min_samples_split':(2, 3, 5, 10, 50, 100), 'n_estimators':(100, 200)}
modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# ENSEMBLE
# MODELO: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=113, verbose=0, warm_start=False)
# PARAMETROS:  {'criterion': ('gini', 'entropy'), 'min_samples_leaf': (1, 2, 5, 10), 'min_samples_split': (2, 3, 5, 10, 50, 100), 'n_estimators': (100, 200)}
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    4.9s
# ...

# %%
m = 5
sm = 1
modelo=list(dic.keys())[m]
print(modelo)
clf,params = modelos.get_modelo(719,modelo,sm)
params = {'bootstrap':[None],
           'criterion':['gini'],
           'max_depth':(10,50),
           'max_features':['auto'],
           'min_samples_leaf':(1,2,3,4,5),
           'min_samples_split':(2,3,5,10,20),
           'n_estimators':(3,10,50,60)
         }

modelo,puntaje = hiperparametros(clf,params)
resultados.append({'mejor_modelo':modelo,'puntaje':puntaje})
# Out:
# ENSEMBLE
# MODELO: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=719, verbose=0, warm_start=False)
# PARAMETROS:  {'bootstrap': [None], 'criterion': ['gini'], 'max_depth': (10, 50), 'max_features': ['auto'], 'min_samples_leaf': (1, 2, 3, 4, 5), 'min_samples_split': (2, 3, 5, 10, 20), 'n_estimators': (3, 10, 50, 60)}
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1398s.) Setting batch_size=2.
# ...

# %%
#del resultados[1] estaban mal referenciados-corri modelo nuevamente
resultadosDB = pd.DataFrame(resultados)
resultadosDB
# Out:
#                                          mejor_modelo   puntaje
# 0   LogisticRegression(C=0.1, class_weight=None, d...  0.369651
# 1   SGDClassifier(alpha=1e-05, average=False, clas...  0.272718
# 2   Perceptron(alpha=0.1, class_weight=None, early...  0.214657
# 3   LinearSVC(C=1e-05, class_weight=None, dual=Tru...  0.263956
# 4   DecisionTreeClassifier(class_weight=None, crit...  0.370192
# 5   KNeighborsClassifier(algorithm='auto', leaf_si...  0.327930
# 6   LabelPropagation(alpha=None, gamma=0.1, kernel...  0.338868
# 7   LabelSpreading(alpha=0.1, gamma=20, kernel='kn...  0.343996
# 8   (DecisionTreeClassifier(class_weight=None, cri...  0.324420
# 9   RidgeClassifier(alpha=10, class_weight=None, c...  0.365873
# 10  (DecisionTreeClassifier(class_weight=None, cri...  0.379376
# 11  (DecisionTreeClassifier(class_weight=None, cri...  0.376534
# 12  (DecisionTreeClassifier(class_weight=None, cri...  0.380454
# 13  (DecisionTreeClassifier(class_weight=None, cri...  0.380454
# ...

# %%
X.shape, XX.shape
yy = resultadosDB.mejor_modelo.iloc[-1].predict(XX.drop(["PID"], axis=1))
yy = yy.astype(np.int)
submission = pd.DataFrame(list(zip(XX.PID, yy)), columns=["PID", "AdoptionSpeed"])
#submission.to_csv("../data/submission.csv", header=True, index=False)
